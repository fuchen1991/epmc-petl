# %%
import os
import re
import sys
import pandas as pd
import random
import numpy as np


out_path = '/home/fuchen/Desktop/experiment/output1208'
model_path = '/home/fuchen/Desktop/experiment/models'
property_path = '/home/fuchen/Desktop/experiment/properties'
equiv_path = '/home/fuchen/Desktop/experiment/equivalences'

# %%
number_seeds = 10
seeds = []
for i in range(0, number_seeds):
    seeds.append(random.randint(0,1000000))
seeds
# Out:
# [473723,
#  574553,
#  332061,
#  982218,
#  638094,
#  494073,
#  927187,
#  193569,
#  420117,
#  623506]

# %%
def run(out_path, property_file, model_file, equiv_file):
    command = 'java -jar -Xms1024m -Xmx5120m epmc-petl.jar check --property-solver propositional-explicit,operator-explicit,pctl-explicit-next,petl-explicit-knowledge,petl-until-uct --prism-flatten false --model-input-type mas --property-input-type petl '
    files = ' --model-input-files ' + model_file + ' ' + equiv_file + ' --property-input-files ' + property_file

    bvalues = [9]
    depths = [9]
    times = [10]
    
    interval = 1
    
    data = list()
    with open(out_path,'a') as fw:
        for seed in seeds:
            for depth in depths:
                for time in times:
                    for bvalue in bvalues:
                        row = dict()
                        row['bvalue'] = bvalue
                        row['depth_limit'] = depth
                        row['time_limit'] = time
                        row['seed'] = seed
                        params = '--uct-depth-limit ' + str(depth) + ' --uct-time-limit ' + str(time) + ' --bvalue '  + str(bvalue) + ' --print-time-interval ' + str(interval) + ' --random-seed ' + str(seed)
                        full_command = command + params + files
                        console_out = os.popen(full_command).read()
                        fw.write(console_out)
                        fw.write('\n')
                        fw.flush()
                        lines = console_out.split('\n')
                        final_res = 0
                        final_rollout = 0
                        final_node = 0
                        for line in lines:
                            if line.startswith('Elapsed time'):
                                elapsed_time = int(re.findall(r"time: (.+?)s Current result:", line)[0])
                                result = re.findall(r"result: (.+?) rollouts:", line)[0]
                                rollout = re.findall(r"rollouts: (.+?) nodes:", line)[0]
                                node = line[line.index('nodes:') + 6 :].strip()
                                row[str(elapsed_time) + 's' + ' result'] = float(result)
                                row[str(elapsed_time) + 's' + ' rollouts'] = int(rollout)
                                row[str(elapsed_time) + 's' + ' nodes'] = int(node)
                            if line.startswith('Final result:'):
                                final_res = line[line.index(':')+1 :].strip()
                            if line.startswith('Number of rollouts:'):
                                final_rollout = line[line.index(':') + 1 :].strip()
                            if line.startswith('Number of nodes:'):
                                final_node = line[line.index(':') + 1 :].strip()
                        row[str(time) + 's' + ' result'] = float(final_res)
                        row[str(time) + 's' + ' rollouts'] = int(final_rollout)
                        row[str(time) + 's' + ' nodes'] = int(final_node)
                        data.append(row)
    return data

# %%
for model_file in os.listdir(model_path):
    for property_file in os.listdir(property_path):
        for equiv_file in os.listdir(equiv_path):
            out_name = os.path.basename(model_file) + '_' + os.path.basename(equiv_file) + '_' +  os.path.basename(property_file)
            full_model_file = os.path.join(model_path, model_file)
            full_property_file = os.path.join(property_path, property_file)
            full_equiv_file = os.path.join(equiv_path, equiv_file)
            full_out_file = os.path.join(out_path, out_name)
            full_out_df = os.path.join(out_path, out_name+"_df.csv")

            data = run(full_out_file, full_property_file, full_model_file, full_equiv_file)
            df = pd.DataFrame(data)
            df.to_csv(full_out_df)

# %%
pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', None)
df_load = pd.read_csv('/home/fuchen/Desktop/experiment/output1208/recon_2.prism_min_F.petl_df.csv')
df_load
# Out:
#    Unnamed: 0  bvalue  depth_limit  time_limit    seed  1s result  \
# 0           0       9            9          10  473723   0.000000
# 1           1       9            9          10  574553   0.000000
# 2           2       9            9          10  332061   0.000000
# 3           3       9            9          10  982218   0.000000
# 4           4       9            9          10  638094   0.000000
# 5           5       9            9          10  494073   0.000000
# 6           6       9            9          10  927187   0.000000
# 7           7       9            9          10  193569   0.000000
# 8           8       9            9          10  420117   0.000000
# 9           9       9            9          10  623506   0.000000
#
#    1s rollouts  1s nodes  2s result  2s rollouts  2s nodes  3s result  \
# 0           96   1005830   0.000000          196   2066752   0.000000
# 1           76   1363008   0.000000          159   3591721   0.000000
# 2          103   2016227   0.000000          176   2782142   0.000000
# 3           39   1495816   0.000000          162   2325455   0.000000
# 4           66    727633   0.000000          162   1955249   0.000000
# 5           45    651803   0.000000          123   2408099   0.000000
# 6           60    484864   0.000000          123   1258622   0.000000
# 7           35   1990619   0.000000          157   2864317   0.000000
# 8           39    645101   0.000000          110   1678612   0.000000
# 9           24   1139068   0.000000          110   2196937   0.000000
#
#    3s rollouts  3s nodes  4s result  4s rollouts  4s nodes  5s result  \
# 0          298   4260866   0.000000          336   7157879   0.000000
# 1          289   4563049   0.000000          416   5605914   0.000000
# 2          313   3998908   0.000000          437   4922818   0.000000
# 3          249   3478299   0.000000          320   5382368   0.000000
# 4          280   2755453   0.000000          351   3910620   0.000000
# 5          189   3123228   0.000000          309   4068416   0.000000
# 6          225   2094969   0.000000          310   3626534   0.000000
# 7          212   5445480   0.000000          249   6000254   0.000000
# 8          193   2475637   0.000000          242   3968439   0.000000
# 9          242   3074513   0.000000          311   4317366   0.000000
#
#    5s rollouts  5s nodes  6s result  6s rollouts  6s nodes  7s result  \
# 0          400   7904231   0.000000          471   8466921   0.000000
# 1          460   7955347   0.000000          563   9528460   0.000000
# 2          560   5846504   0.000000          678   6729009   0.000000
# 3          408   6034789   0.000000          563   6882359   0.000000
# 4          404   6253623   0.000000          459   6811860   0.000000
# 5          412   5332327   0.000000          512   6294209   0.000000
# 6          399   4312569   0.000000          446   4771637   0.000000
# 7          340   7122062   0.000000          413   7652347   0.000000
# 8          326   4598909   0.000000          379   5013708   0.000000
# 9          415   5169484   0.000000          453   7078118   0.000000
#
#    7s rollouts  7s nodes  8s result  8s rollouts  8s nodes  9s result  \
# 0          556  10138589   0.000000          621  10799832   0.000000
# 1          612  10154857   0.000000          719  11329796   0.000000
# 2          772   7941019   0.000000          871   8951648   0.000000
# 3          618   8546493   0.000000          712   9230148   0.000000
# 4          517   7397317   0.000000          587   8017920   0.000000
# 5          572   7363870   0.000000          680   8537312   0.000000
# 6          546   5804657   0.000000          632   6448940   0.000000
# 7          481   9093972   0.000000          557   9824815   0.000000
# 8          413   5953391   0.000000          521   6527285   0.000000
# 9          539   8338790   0.000000          615   8891881   0.000000
#
#    9s rollouts  9s nodes  10s result  10s rollouts  10s nodes
# 0          707  11895628    0.000000           826   13383276
# 1          790  12757902    0.000000           886   13521679
# 2          945  10458195    0.000000          1053   11379691
# 3          813  10183940    0.000000           897   11895402
# 4          621   8705239    0.000000           647   10137271
# 5          775   9078826    0.000000           878    9917363
# 6          649   7724024    0.000000           695    7919285
# 7          609  10351414    0.000000           649   11498999
# 8          610   7400621    0.000000           729    8288667
# 9          685  10014445    0.000000           796   10637124

# %%
col_mean = df_load.mean()

pd.set_option('display.float_format', lambda x: '%.6f' % x)
pd.DataFrame(col_mean)
# Out:
#                            0
# Unnamed: 0          4.500000
# bvalue              9.000000
# depth_limit         9.000000
# time_limit         10.000000
# seed           565910.100000
# 1s result           0.000000
# 1s rollouts        58.300000
# 1s nodes      1151996.900000
# 2s result           0.000000
# 2s rollouts       147.800000
# 2s nodes      2312790.600000
# 3s result           0.000000
# 3s rollouts       249.000000
# 3s nodes      3527040.200000
# 4s result           0.000000
# 4s rollouts       328.100000
# 4s nodes      4896060.800000
# 5s result           0.000000
# 5s rollouts       412.400000
# 5s nodes      6052984.500000
# 6s result           0.000000
# 6s rollouts       493.700000
# 6s nodes      6922862.800000
# 7s result           0.000000
# 7s rollouts       562.600000
# 7s nodes      8073295.500000
# 8s result           0.000000
# 8s rollouts       651.500000
# 8s nodes      8855957.700000
# 9s result           0.000000
# 9s rollouts       720.400000
# 9s nodes      9857023.400000
# 10s result          0.000000
# 10s rollouts      805.600000
# 10s nodes    10857875.700000

# %%
#pd.set_option('precision', 3)
#pd.set_option('display.float_format', lambda x: '%.3f' % x)

df_max = pd.DataFrame(data_max)
df_max.to_csv('/home/fuchen/Desktop/experiment/max_60s_min.csv')
df_max
# Out:
#    bvalue  depth_limit  time_limit    seed  1s result  1s rollouts  1s nodes  \
# 0       9            9          60  666750   0.000194         1792   1975391
# 1       9            9          60   31793   0.000440         1239   1432609
# 2       9            9          60  611067   0.002681         1411   1604716
# 3       9            9          60  588991   0.003363         1366   1528894
# 4       9            9          60  279495   0.009454         1411   1576116
# 5       9            9          60  599829   0.000844         1408   1612246
# 6       9            9          60  409248   0.003758         1225   1414818
# 7       9            9          60  901217   0.002185         1241   1429137
# 8       9            9          60  488080   0.003337         1429   1598337
# 9       9            9          60  680342   0.000117         1299   1470355
#
#    2s result  2s rollouts  2s nodes  3s result  3s rollouts  3s nodes  \
# 0   0.000049         3920   3900614   0.000049         6199   5727628
# 1   0.000440         2811   2953135   0.000440         4249   4211708
# 2   0.000087         3007   3072570   0.000087         4829   4674580
# 3   0.000915         2881   2978099   0.000285         4672   4533606
# 4   0.000429         3052   3139124   0.000086         4522   4412588
# 5   0.000462         2997   3116955   0.000053         4804   4638407
# 6   0.000528         2806   2921744   0.000054         4654   4546352
# 7    0.000003         44650   27041781         nan           nan
# 8    0.000003         44527   27089986    0.000003  44528.000000
# 9    0.000003         44064   27057553         nan           nan
#
#         59s nodes  60s result  60s rollouts  60s nodes
# 0 27158954.000000    0.000003         44100   27169152
# 1 27081322.000000    0.000003         44566   27099487
# 2 27115275.000000    0.000003         45082   27134235
# 3             nan    0.000003         44217   27129380
# 4             nan    0.000003         44029   27119673
# 5             nan    0.000003         44593   27120833
# 6             nan    0.000003         44472   27123047
# 7             nan    0.000003         44708   27074593
# 8 27089986.000000    0.000003         44580   27111559
# 9             nan    0.000003         44126   27083225

# %%
col_mean = df_max.mean()

pd.set_option('display.float_format', lambda x: '%.6f' % x)
pd.DataFrame(col_mean)
# Out:
#                            0
# bvalue              9.000000
# depth_limit         9.000000
# time_limit         60.000000
# seed           525681.200000
# 1s result           0.002637
# 1s rollouts      1382.100000
# 1s nodes      1564261.900000
# 2s result           0.000350
# 2s rollouts      3016.800000
# 2s nodes      3107709.100000
# 3s result           0.000165
# 3s rollouts      4701.600000
# 3s nodes      4554061.100000
# 4s result           0.000143
# 4s rollouts      6433.600000
# 4s nodes      5912595.300000
# 5s result           0.000097
# 5s rollouts      8072.000000
# 5s nodes      7101397.000000
# 6s result           0.000097
# 6s rollouts      9717.600000
# 6s nodes      8284343.800000
# 7s result           0.000061
# 7s rollouts     11310.700000
# 7s nodes      9387413.200000
# 8s result           0.000053
# 8s rollouts     13060.600000
# 8s nodes     10596783.000000
# 9s result           0.000042
# 9s rollouts     14567.800000
# 9s nodes     11584563.700000
# 10s result          0.000037
# 10s rollouts    16161.300000
# 10s nodes    12568383.900000
# 11s result          0.000035
# 11s rollouts    17850.600000
# 11s nodes    13591834.500000
# 12s result          0.000027
# 12s rollouts    19493.100000
# 12s nodes    14548676.400000
# 13s result          0.000024
# 13s rollouts    20950.300000
# 13s nodes    15379119.800000
# 14s result          0.000016
# 14s rollouts    22562.000000
# 14s nodes    16259135.900000
# 15s result          0.000016
# 15s rollouts    24263.300000
# 15s nodes    17203317.700000
# 16s result          0.000016
# 16s rollouts    25930.300000
# 16s nodes    18120930.300000
# 17s result          0.000016
# 17s rollouts    27508.400000
# 17s nodes    18973816.600000
# 18s result          0.000014
# 18s rollouts    29073.100000
# 18s nodes    19807949.900000
# 19s result          0.000014
# 19s rollouts    30713.800000
# 19s nodes    20632002.700000
# 20s result          0.000014
# 20s rollouts    32379.400000
# 20s nodes    21465094.300000
# 21s result          0.000013
# 21s rollouts    33793.200000
# 21s nodes    22160332.000000
# 22s result          0.000013
# 22s rollouts    35131.000000
# 22s nodes    22830662.200000
# 23s result          0.000013
# 23s rollouts    36654.500000
# 23s nodes    23540975.500000
# 24s result          0.000013
# 24s rollouts    38076.300000
# 24s nodes    24223627.200000
# 25s result          0.000013
# 25s rollouts    39326.800000
# 25s nodes    24812282.900000
# 26s result          0.000013
# 26s rollouts    39821.500000
# 26s nodes    25041706.600000
# 27s result          0.000013
# 27s rollouts    40216.000000
# 27s nodes    25233078.800000
# 28s result          0.000011
# 28s rollouts    41372.100000
# 28s nodes    25754612.000000
# 29s result          0.000007
# 29s rollouts    41586.800000
# 29s nodes    25850225.900000
# 30s result          0.000006
# 30s rollouts    41791.700000
# 30s nodes    25944630.200000
# 31s result          0.000005
# 31s rollouts    42224.000000
# 31s nodes    26144638.100000
# 32s result          0.000003
# 32s rollouts    42381.000000
# 32s nodes    26213613.200000
# 33s result          0.000003
# 33s rollouts    42589.300000
# 33s nodes    26304597.100000
# 34s result          0.000003
# 34s rollouts    42688.800000
# 34s nodes    26347489.700000
# 35s result          0.000003
# 35s rollouts    42892.700000
# 35s nodes    26438488.200000
# 36s result          0.000003
# 36s rollouts    42968.500000
# 36s nodes    26469922.200000
# 37s result          0.000003
# 37s rollouts    43144.500000
# 37s nodes    26545133.200000
# 38s result          0.000003
# 38s rollouts    43199.500000
# 38s nodes    26570034.600000
# 39s result          0.000003
# 39s rollouts    43345.400000
# 39s nodes    26638212.100000
# 40s result          0.000003
# 40s rollouts    43416.200000
# 40s nodes    26668950.000000
# 41s result          0.000003
# 41s rollouts    43538.100000
# 41s nodes    26718921.600000
# 42s result          0.000003
# 42s rollouts    43609.900000
# 42s nodes    26749661.700000
# 43s result          0.000003
# 43s rollouts    43704.000000
# 43s nodes    26791061.700000
# 44s result          0.000003
# 44s rollouts    43765.400000
# 44s nodes    26817969.100000
# 45s result          0.000003
# 45s rollouts    43841.700000
# 45s nodes    26851868.300000
# 46s result          0.000003
# 46s rollouts    43888.200000
# 46s nodes    26873422.400000
# 47s result          0.000003
# 47s rollouts    43965.000000
# 47s nodes    26907861.600000
# 48s result          0.000003
# 48s rollouts    44007.000000
# 48s nodes    26925643.900000
# 49s result          0.000003
# 49s rollouts    44074.900000
# 49s nodes    26953709.100000
# 50s result          0.000003
# 50s rollouts    44111.400000
# 50s nodes    26970011.900000
# 51s result          0.000003
# 51s rollouts    44168.800000
# 51s nodes    26993740.100000
# 52s result          0.000003
# 52s rollouts    44199.300000
# 52s nodes    27009286.000000
# 53s result          0.000003
# 53s rollouts    44245.500000
# 53s nodes    27029577.700000
# 54s result          0.000003
# 54s rollouts    44275.000000
# 54s nodes    27044344.500000
# 55s result          0.000003
# 55s rollouts    44312.200000
# 55s nodes    27059184.400000
# 56s result          0.000003
# 56s rollouts    44341.800000
# 56s nodes    27072904.600000
# 57s result          0.000003
# 57s rollouts    44379.200000
# 57s nodes    27087183.600000
# 58s result          0.000003
# 58s rollouts    44400.100000
# 58s nodes    27096636.200000
# 59s result          0.000003
# 59s rollouts    44539.000000
# 59s nodes    27111384.250000
# 60s result          0.000003
# 60s rollouts    44447.300000
# 60s nodes    27116518.400000

# %%
csvpath = '/home/fuchen/Desktop/experiment/backup/max/max_60s_dell_65.csv'
df = pd.read_csv(csvpath,index_col=[0])
df
# Out:
#    bvalue  depth_limit  time_limit    seed  1s result  1s rollouts  1s nodes  \
# 0       9            9          60  456581   0.268786         1543   1812963
# 1       9            9          60  376669   0.868898         1212   1484749
# 2       9            9          60  177920   0.868898         1199   1410787
# 3       9            9          60   13812   0.511968         1055   1304196
# 4       9            9          60  405222   0.868898         1014   1354892
# 5       9            9          60  547322   0.053470         1129   1320121
# 6       9            9          60  241215   0.069633         1567   1558399
# 7       9            9          60  794653   0.868898         1100   1409805
# 8       9            9          60  663448   0.191804         1287   1445460
# 9       9            9          60  479512   0.000976         1153   1417671
#
#    2s result  2s rollouts  2s nodes  ...  57s nodes  58s result  58s rollouts  \
# 0   0.868898         3491   2942665  ...   25499612    0.909199         83743
# 1   0.868898         2596   2835328  ...   23373463    0.909199         70049
# 2   0.868898         2486   2847832  ...   26460500    0.982812         45018
# 3   0.511968         2326   2346888  ...   25839770    0.909199         63091
# 4   0.868898         2158   2495081  ...   21566124    0.982812         66075
# 5   0.191804         2828   2555396  ...   16766381    0.878027        107291
# 6   0.115165         3322   3054852  ...   26341662    0.909199         48211
# 7   0.868898         2280   2590522  ...   21797845    0.982812         73245
# 8   0.868898         2470   2574615  ...   25352597    0.982812         58127
# 9   0.638648         2936   2932436  ...   24599893    0.909199         74906
#
#    58s nodes  59s result  59s rollouts  59s nodes  60s result  60s rollouts  \
# 0   25697545    0.909199         83744   25698031    0.909199         83958
# 1   23445199    0.909199         71168   23605154    0.909199         72349
# 2   26491618    0.982812         45019   26493226    0.982812         45061
# 3   25839770    0.909199         63373   25886754    0.909199         63420
# 4   21683139    0.982812         67212   21787426    0.982812         68276
# 5   16799919    0.878027        109330   16840109    0.878027        111296
# 6   26361482    0.909199         48212   26361482    0.909199         48325
# 7   21908222    0.982812         74387   22005728    0.982812         75558
# 8   25426191    0.982812         58128   25426191    0.982812         58167
# 9   24684616    0.909199         75838   25456632    0.909199         75860
#
#    60s nodes
# 0   25870673
# 1   23682607
# 2   26519817
# 3   25896132
# 4   21894875
# 5   16878540
# 6   26398454
# 7   22112545
# 8   25431817
# 9   25477282
#
# [10 rows x 184 columns]

# %%
pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', None)

col_mean = df.mean(axis=0)



#pd.set_option('display.float_format', lambda x: '%.3f' % x)
#df_mean = pd.DataFrame(col_mean)
#col_mean.to_frame()
# Out:
# 0.4572227465

# %%
names = list()
values = list()
values2 = list()
for i in range(0,60):
    names.append(str(i+1))
    key = str(i+1) + 's result'
    values.append(float('%.3f' % col_mean[key]))
    values2.append(float(0.983))

# %%
import matplotlib.pyplot as plt
from pylab import * 
#mpl.rcParams['font.sans-serif'] = ['SimHei']

x = range(len(values))
plt.plot(x, values, label='Results of Algorithm 2')
plt.plot(x, values2, linestyle="--",label='Exact results')
plt.legend(loc=4)
plt.ylim(0, 1.0)
#plt.margins(0)
plt.xlabel("time(s)")
plt.ylabel("result")
#plt.title("Pmax")
plt.savefig('max_appro.pdf',dpi=200, bbox_inches='tight')
plt.show()
plt.close()

# %%
values2
# Out:
# [0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983,
#  0.983]
